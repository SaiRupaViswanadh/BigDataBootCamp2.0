# %% [markdown]
# # PandasAssignment with Answers

# %% [markdown]
# Q1.) How do you load a CSV file into a Pandas DataFrame?

# %%
#Answer
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Q2.) How do you check the data type of a column in a Pandas DataFrame?

# %% [markdown]
# Ans:) To check the data type in pandas DataFrame we can use the “dtype” attribute.
# The attribute returns a series with the data type of each column.
# and the column names of the DataFrame are represented as the index of the resultant series object and
# the corresponding data types are returned as values of the series object.

# %%
#to find datatype of all columns
result=df.dtypes
result
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#to find datatype of one column
res_col1=df['Age'].dtypes
res_col1
# Out:
# dtype('float64')

# %% [markdown]
# Q3.) How do you select rows from a Pandas DataFrame based on a condition?

# %%
#Answer
#Select rows with Age < 16
res_age=df[df['Age'] < 16]
res_age
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 831          832         1       2          Richards, Master. George Sibley
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %% [markdown]
# Q4.) How do you rename columns in a Pandas DataFrame?

# %%
# Answer
# Before renaming the columns
dfnew=df.copy()
print(dfnew.columns)
   
dfnew.rename(columns = {'Pclass':'PassengerClass', 'Fare':'Price'}, inplace = True)
   
# After renaming the columns
print(dfnew.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'PassengerClass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Price', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Q5.) How do you drop columns in a Pandas DataFrame?

# %%
#Answer
dfnew.head()
# Out:
#    PassengerId  Survived  PassengerClass  \
# 0            1         0               3
# 1            2         1               1
# 2            3         1               3
# 3            4         1               1
# 4            5         0               3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket    Price Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
dfnew.drop('PassengerClass', axis=1, inplace=True)
dfnew.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket    Price Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# Q6.) How do you find the unique values in a column of a Pandas DataFrame?

# %%
#Answer
#by unique
dfnew['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# Q7.) How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
#Answer by using isna()
dfnew.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Price            0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Q8.) How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
dfnew.fillna('xx')
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# Q9.) How do you concatenate two Pandas DataFrames?

# %% [markdown]
# Ans:) We can use the concat function in pandas to append either columns or rows from one DataFrame to another.

# %%
c1=dfnew.head(10)
c1
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
# 5            6         0                                   Moran, Mr. James
# 6            7         0                            McCarthy, Mr. Timothy J
# 7            8         0                     Palsson, Master. Gosta Leonard
# 8            9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10         1                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket    Price Cabin Embarked
# ...

# %%
c2=dfnew.tail(5)
c2
# Out:
#      PassengerId  Survived                                      Name     Sex  \
# 886          887         0                     Montvila, Rev. Juozas    male
# 887          888         1              Graham, Miss. Margaret Edith  female
# 888          889         0  Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890         1                     Behr, Mr. Karl Howell    male
# 890          891         0                       Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch      Ticket  Price Cabin Embarked
# 886  27.0      0      0      211536  13.00   NaN        S
# 887  19.0      0      0      112053  30.00   B42        S
# 888   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889  26.0      0      0      111369  30.00  C148        C
# 890  32.0      0      0      370376   7.75   NaN        Q

# %%
# Reset the index values to the second dataframe appends properly
c2 =c2.reset_index(drop=True)
# drop=True option avoids adding new index column with old index values
c2
# Out:
#    PassengerId  Survived                                      Name     Sex  \
# 0          887         0                     Montvila, Rev. Juozas    male
# 1          888         1              Graham, Miss. Margaret Edith  female
# 2          889         0  Johnston, Miss. Catherine Helen "Carrie"  female
# 3          890         1                     Behr, Mr. Karl Howell    male
# 4          891         0                       Dooley, Mr. Patrick    male
#
#     Age  SibSp  Parch      Ticket  Price Cabin Embarked
# 0  27.0      0      0      211536  13.00   NaN        S
# 1  19.0      0      0      112053  30.00   B42        S
# 2   NaN      1      2  W./C. 6607  23.45   NaN        S
# 3  26.0      0      0      111369  30.00  C148        C
# 4  32.0      0      0      370376   7.75   NaN        Q

# %%
# Stack the DataFrames on top of each other
vertical_stack = pd.concat([c1, c2], axis=0)
vertical_stack
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
# 5            6         0                                   Moran, Mr. James
# 6            7         0                            McCarthy, Mr. Timothy J
# 7            8         0                     Palsson, Master. Gosta Leonard
# 8            9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10         1                Nasser, Mrs. Nicholas (Adele Achem)
# 0          887         0                              Montvila, Rev. Juozas
# ...

# %%
#reindex
vertical_stack =vertical_stack.reset_index(drop=True)
vertical_stack
# Out:
#     PassengerId  Survived                                               Name  \
# 0             1         0                            Braund, Mr. Owen Harris
# 1             2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             3         1                             Heikkinen, Miss. Laina
# 3             4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4             5         0                           Allen, Mr. William Henry
# 5             6         0                                   Moran, Mr. James
# 6             7         0                            McCarthy, Mr. Timothy J
# 7             8         0                     Palsson, Master. Gosta Leonard
# 8             9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9            10         1                Nasser, Mrs. Nicholas (Adele Achem)
# 10          887         0                              Montvila, Rev. Juozas
# ...

# %%
# Place the DataFrames side by side
horizontal_stack = pd.concat([c1, c2], axis=1)
horizontal_stack
# Out:
#    PassengerId Survived                                               Name  \
# 0            1        0                            Braund, Mr. Owen Harris
# 1            2        1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3        1                             Heikkinen, Miss. Laina
# 3            4        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5        0                           Allen, Mr. William Henry
# 5            6        0                                   Moran, Mr. James
# 6            7        0                            McCarthy, Mr. Timothy J
# 7            8        0                     Palsson, Master. Gosta Leonard
# 8            9        1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10        1                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age SibSp  Parch            Ticket    Price Cabin  ... Survived  \
# ...

# %% [markdown]
# Q10.) How do you merge two Pandas DataFrames on a specific column?

# %%
#Answer
# creating a dataframe
df1 = pd.DataFrame({'Name':['Raju', 'Rani', 'Geeta', 'Sita', 'Sohit'],
                    'Marks':[80, 90, 75, 88, 59]})
  
# creating another dataframe with different data
df2 = pd.DataFrame({'Name':['Raju', 'Divya', 'Geeta', 'Sita'],
                    'Grade':['A', 'A', 'B', 'A'],
                    'Rank':[3, 1, 4, 2 ],
                    'Gender':['Male', 'Female', 'Female', 'Female']})
# display df1
display(df1)
  
# display df2
display(df2)
# Out:
#     Name  Marks
# 0   Raju     80
# 1   Rani     90
# 2  Geeta     75
# 3   Sita     88
# 4  Sohit     59
#     Name Grade  Rank  Gender
# 0   Raju     A     3    Male
# 1  Divya     A     1  Female
# 2  Geeta     B     4  Female
# 3   Sita     A     2  Female

# %%
df1.merge(df2)
# Out:
#     Name  Marks Grade  Rank  Gender
# 0   Raju     80     A     3    Male
# 1  Geeta     75     B     4  Female
# 2   Sita     88     A     2  Female

# %%
df2.merge(df1)
# Out:
#     Name Grade  Rank  Gender  Marks
# 0   Raju     A     3    Male     80
# 1  Geeta     B     4  Female     75
# 2   Sita     A     2  Female     88

# %%
df1.merge(df2[['Name','Rank']])
# Out:
#     Name  Marks  Rank
# 0   Raju     80     3
# 1  Geeta     75     4
# 2   Sita     88     2

# %%
# applying merge with more parameters
df1.merge(df2[['Grade', 'Name']], on = 'Name', how = 'left')
# Out:
#     Name  Marks Grade
# 0   Raju     80     A
# 1   Rani     90   NaN
# 2  Geeta     75     B
# 3   Sita     88     A
# 4  Sohit     59   NaN

# %%
# applying merge with more parameters
df1.merge(df2[['Grade', 'Name']], on = 'Name', how = 'right')
# Out:
#     Name  Marks Grade
# 0   Raju   80.0     A
# 1  Divya    NaN     A
# 2  Geeta   75.0     B
# 3   Sita   88.0     A

# %%
# applying merge with more parameters
df2.merge(df1[['Marks', 'Name']])
# Out:
#     Name Grade  Rank  Gender  Marks
# 0   Raju     A     3    Male     80
# 1  Geeta     B     4  Female     75
# 2   Sita     A     2  Female     88

# %% [markdown]
# Q11.) How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %% [markdown]
# Ans:) Dataframe.aggregate() function is used to apply some aggregation across one or more column. Aggregate using callable, string, dict, or list of string/callables. Most frequently used aggregations are:
#
# sum: Return the sum of the values for the requested axis
# min: Return the minimum of the values for the requested axis
# max: Return the maximum of the values for the requested axis
#
# Syntax: DataFrame.aggregate(func, axis=0, *args, **kwargs)
# Parameters:
# func : callable, string, dictionary, or list of string/callables. Function to use for aggregating the data. If a function, must either work when passed a DataFrame or when passed to DataFrame.apply. For a DataFrame, can pass a dict, if the keys are DataFrame column names.
# axis : (default 0) {0 or ‘index’, 1 or ‘columns’} 0 or ‘index’: apply function to each column. 1 or ‘columns’: apply function to each row.
#
# Returns: Aggregated DataFrame

# %%
import pandas as pd
data= pd.read_csv('https://raw.githubusercontent.com/geoninja/Uber-Data-Analysis/master/Data/weather.csv')
data
# Out:
#                STATION                STATION_NAME      DATE  PRCP  SNWD  \
# 0    GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140101  0.00   0.0
# 1    GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140102  0.33   0.0
# 2    GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140103  0.29   5.9
# 3    GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140104  0.00   5.9
# 4    GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140105  0.14   3.9
# ..                 ...                         ...       ...   ...   ...
# 725  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20151227  0.12   0.0
# 726  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20151228  0.03   0.0
# 727  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20151229  0.45   0.0
# 728  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20151230  0.19   0.0
# 729  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20151231  0.03   0.0
#
#      SNOW  TMAX  TMIN  AWND
# 0     0.0    33    24   5.6
# 1     3.1    33    18  12.3
# ...

# %%
data[:10]
# Out:
#              STATION                STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140101  0.00   0.0   0.0
# 1  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140102  0.33   0.0   3.1
# 2  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140103  0.29   5.9   3.3
# 3  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140104  0.00   5.9   0.0
# 4  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140105  0.14   3.9   0.0
# 5  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140106  0.36   1.2   0.0
# 6  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140107  0.00   0.0   0.0
# 7  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140108  0.00   0.0   0.0
# 8  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140109  0.00   0.0   0.0
# 9  GHCND:USW00094728  NY CITY CENTRAL PARK NY US  20140110  0.11   0.0   0.0
#
#    TMAX  TMIN  AWND
# 0    33    24   5.6
# 1    33    18  12.3
# 2    18     9  10.5
# 3    29     8   4.9
# ...

# %%
# Applying aggregation across all the columns 
# sum and min will be found for each 
# numeric type column in df dataframe
  
data.aggregate(['sum', 'min', 'max'])
# Out:
#                                                STATION  \
# sum  GHCND:USW00094728GHCND:USW00094728GHCND:USW000...
# min                                  GHCND:USW00094728
# max                                  GHCND:USW00094728
#
#                                           STATION_NAME         DATE   PRCP  \
# sum  NY CITY CENTRAL PARK NY USNY CITY CENTRAL PARK...  14706337876  94.76
# min                         NY CITY CENTRAL PARK NY US     20140101   0.00
# max                         NY CITY CENTRAL PARK NY US     20151231   4.97
#
#       SNWD  SNOW   TMAX   TMIN     AWND
# sum  839.6  99.1  45981  35295 -26137.0
# min    0.0   0.0     17      2  -9999.0
# max   18.9  11.0     97     82     14.5

# %%
# We are going to find aggregation for these columns
data.aggregate({"PRCP":['sum', 'min'],
              "AWND":['max', 'min']})
# Out:
#       PRCP    AWND
# sum  94.76     NaN
# min   0.00 -9999.0
# max    NaN    14.5

# %% [markdown]
# Q12.) How do you pivot a Pandas DataFrame?

# %% [markdown]
# Ans:) pandas.pivot(index, columns, values) function produces pivot table based on 3 columns of the DataFrame. Uses unique values from index / columns and fills with values.
#
# Parameters:
# index[ndarray] : Labels to use to make new frame’s index
# columns[ndarray] : Labels to use to make new frame’s columns
# values[ndarray] : Values to use for populating new frame’s values
#
# Returns: Reshaped DataFrame
# Exception: ValueError raised if there are any duplicates.

# %%
# Create a simple dataframe
  
# importing pandas as pd
import pandas as pd
  
# creating a dataframe
df = pd.DataFrame({'A': ['John', 'Boby', 'Mina'],
      'B': ['Masters', 'Graduate', 'Graduate'],
      'C': [27, 23, 21]})
  
df
# Out:
#       A         B   C
# 0  John   Masters  27
# 1  Boby  Graduate  23
# 2  Mina  Graduate  21

# %%
# values can be an object or a list
df.pivot('A', 'B', 'C')
# Out:
# /tmp/ipykernel_94/230739492.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df.pivot('A', 'B', 'C')
# B     Graduate  Masters
# A
# Boby      23.0      NaN
# John       NaN     27.0
# Mina      21.0      NaN

# %%
# value is a list
df.pivot(index ='A', columns ='B', values =['C', 'A'])
# Out:
#             C                A
# B    Graduate Masters Graduate Masters
# A
# Boby       23     NaN     Boby     NaN
# John      NaN      27      NaN    John
# Mina       21     NaN     Mina     NaN

# %%
#Raise ValueError when there are any index, columns combinations with multiple values.
# creating a dataframe
df = pd.DataFrame({'A': ['John', 'John', 'Mina'],
      'B': ['Masters', 'Masters', 'Graduate'],
      'C': [27, 23, 21]})
  
  
df.pivot('A', 'B', 'C')
# Out:
# /tmp/ipykernel_94/330226886.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df.pivot('A', 'B', 'C')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 8
#       1 #Raise ValueError when there are any index, columns combinations with multiple values.
#       2 # creating a dataframe
#       3 df = pd.DataFrame({'A': ['John', 'John', 'Mina'],
#       4       'B': ['Masters', 'Masters', 'Graduate'],
#       5       'C': [27, 23, 21]})
# ----> 8 df.pivot('A', 'B', 'C')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %% [markdown]
# Q13.) How do you change the data type of a column in a Pandas DataFrame?

# %% [markdown]
# Ans:) DataFrame.astype() method is used to cast pandas object to a specified dtype.
# This function also provides the capability to convert any suitable existing column to a categorical type.

# %%
# importing pandas as pd
import pandas as pd
 
# sample dataframe
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': ['a', 'b', 'c', 'd', 'e'],
    'C': [1.1, '1.0', '1.3', 2, 5]})
df
print(df.dtypes)
# Out:
# A     int64
# B    object
# C    object
# dtype: object

# %%
# converting all columns to string type
df = df.astype(str)
print(df.dtypes)
# Out:
# A    object
# B    object
# C    object
# dtype: object

# %%
convert_dt={'A': int,'C':float}
df=df.astype(convert_dt)
print(df.dtypes)
# Out:
# A      int64
# B     object
# C    float64
# dtype: object

# %% [markdown]
# Q14.) How do you sort a Pandas DataFrame by a specific column?

# %%
#Answer
import pandas as pd
details = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
  
# Sort the rows of dataframe by  'Name' 
# column inplace
details.sort_values(by = 'Age', inplace = True)
  
# show the resultant Dataframe
details
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# Q15.) How do you create a copy of a Pandas DataFrame?

# %% [markdown]
# Ans:) Syntax: DataFrame.copy(deep=True)
#
# When deep=True (default), a new object will be created with a copy of the calling object’s data and indices.
# Modifications to the data or indices of the copy will not be reflected in the original object (see notes below).

# %%
AB=details.copy(deep=True)
AB
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# Q16.) How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
#Answer by using loc
display(AB.loc[(AB['Age']>60) & (AB['Survived']>0)])
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 570          571         1       2                         Harris, Mr. George
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 829  female  62.0      0      0       113572  80.0000   B28      NaN
# 570    male  62.0      0      0  S.W./PP 752  10.5000   NaN        S
# 275  female  63.0      1      0        13502  77.9583    D7        S
# 483  female  63.0      0      0         4134   9.5875   NaN        S
# 630    male  80.0      0      0        27042  30.0000   A23        S

# %% [markdown]
# Q17.) How do you calculate the mean of a column in a Pandas DataFrame?

# %%
#Answer
AB['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# Q18.) How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
#Answer
AB['Age'].std()
# Out:
# 14.526497332334037

# %% [markdown]
# Q19.) How do you calculate the correlation between two columns in a Pandas DataFrame?

# %% [markdown]
# Ans:) Correlation is used to summarize the strength and direction of the linear association between two quantitative variables. It is denoted by r and values between -1 and +1. A positive value for r indicates a positive association, and a negative value for r indicates a negative association.
#
# By using corr() function we can get the correlation between two columns in the dataframe.
#
# Syntax:
# dataframe[‘first_column’].corr(dataframe[‘second_column’])
#
# where,
#
# dataframe is the input dataframe
# first_column is correlated with second_column of the dataframe

# %%
# import pandas module
import pandas as pd
 
# create dataframe with 3 columns
data = pd.DataFrame({
    "column1": [12, 23, 45, 67],
    "column2": [67, 54, 32, 1],
    "column3": [34, 23, 56, 23]
}
)
# get correlation between element wise
print(data.corr())
# Out:
#               column1   column2       column3
# column1  1.000000e+00 -0.997048  4.993708e-17
# column2 -9.970477e-01  1.000000  7.347000e-02
# column3  4.993708e-17  0.073470  1.000000e+00

# %%
# correlation between column 1 and column2
print(data['column1'].corr(data['column2']))
# Out:
# -0.9970476685163736

# %% [markdown]
# Q20.) How do you select specific columns in a DataFrame using their labels?

# %%
#Ans:) 
# import pandas
import pandas as pd
 
# List of Tuples
employees = [('Stuti', 28, 'Varanasi', 20000),
            ('Saumya', 32, 'Delhi', 25000),
            ('Aaditya', 25, 'Mumbai', 40000),
            ('Saumya', 32, 'Delhi', 35000),
            ('Saumya', 32, 'Delhi', 30000),
            ('Saumya', 32, 'Mumbai', 20000),
            ('Aaditya', 40, 'Dehradun', 24000),
            ('Seema', 32, 'Delhi', 70000)
            ]
 
# Create a DataFrame object from list
df = pd.DataFrame(employees,
                columns =['Name', 'Age',
                        'City', 'Salary'])
#single column
display(df[['City']])
 
# Using the operator [] to
# select multiple columns
result = df[["Name", "Age", "Salary"]]
 
# Show the dataframe
result
# Out:
#        City
# 0  Varanasi
# 1     Delhi
# 2    Mumbai
# 3     Delhi
# 4     Delhi
# 5    Mumbai
# 6  Dehradun
# 7     Delhi
#       Name  Age  Salary
# 0    Stuti   28   20000
# 1   Saumya   32   25000
# 2  Aaditya   25   40000
# 3   Saumya   32   35000
# 4   Saumya   32   30000
# 5   Saumya   32   20000
# 6  Aaditya   40   24000
# 7    Seema   32   70000

# %% [markdown]
# Q21.) How do you select specific rows in a DataFrame using their indexes?

# %%
#Answer
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Accessing rowss by index
df[5:11]
# Out:
#     PassengerId  Survived  Pclass  \
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket     Fare Cabin Embarked
# 5       0   330877   8.4583   NaN        Q
# 6       0    17463  51.8625   E46        S
# 7       1   349909  21.0750   NaN        S
# ...

# %%
df[5:]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[5:20:5]
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 5             6         0       3                  Moran, Mr. James    male
# 10           11         1       3   Sandstrom, Miss. Marguerite Rut  female
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 5    NaN      0      0   330877   8.4583   NaN        Q
# 10   4.0      1      1  PP 9549  16.7000    G6        S
# 15  55.0      0      0   248706  16.0000   NaN        S

# %%
#by loc and iloc
#accessing rows
display(df.loc[5])
display(df.loc[5:8])
display(df.iloc[5])
display(df.iloc[5:8])
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
# ...

# %% [markdown]
# Q22.) How do you sort a DataFrame by a specific column?

# %%
#Answer
df.sort_values('Age',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values('Age',ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# Q23.) How do you create a new column in a DataFrame based on the values of another column?

# %%
#Answer
df['new_col']=df['Age']*2
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S     44.0
# 1      0          PC 17599  71.2833   C85        C     76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     52.0
# 3      0            113803  53.1000  C123        S     70.0
# ...

# %% [markdown]
# Q24.) How do you remove duplicates from a DataFrame?

# %% [markdown]
# Ans:) Pandas drop_duplicates() method helps in removing duplicates from the Pandas Dataframe In Python.

# %%
import pandas as pd
  
data = {
    "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
    "B": [50, 40, 40, 30, 50],
    "C": [True, False, False, False, True]
}
  
df = pd.DataFrame(data)

display("Original data", df)
  
display(df.drop_duplicates())
# Out:
# 'Original data'
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 2  TeamB  40  False
# 3  TeamC  30  False
# 4  TeamA  50   True
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 3  TeamC  30  False

# %% [markdown]
# Q25.) What is the difference between .loc and .iloc in Pandas?

# %%
#Ans:
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
display(df.head(10))
display('loc',df.loc[5:10])
display('iloc',df.iloc[5:10])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
dfnew=df.set_index('PassengerId')
display(dfnew.head())
display('loc',dfnew.loc[5:10])#PassengerId ind
display('iloc',dfnew.iloc[5:10])#original index
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...
